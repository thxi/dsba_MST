# %%
import pandas as pd

# %%
e = pd.read_csv('../data/mst_boruvka_v2.csv')
e_json = list()

# %%
cities = pd.read_csv('../data/ru_lat_lng_clear_v2.csv')
coord = dict()
for (_, city) in cities.iterrows():
    coord[city['name']] = (city['lat'], city['lng'])

# %%
for (_, edge) in e.iterrows():
#     p = {'city1': edge['node1'], 'city2' : edge['node2']}
    p = {'city1': {'name':edge['node1'], 'coord': coord[edge['node1']]}, \
         'city2': {'name':edge['node2'], 'coord': coord[edge['node2']]}}
    e_json.append(p)

# %%
import json

# %%
e_json
# Out:
# [{'city1': {'name': 'Angarsk', 'coord': (52.544357999999995, 103.88824)},
#   'city2': {'name': 'Irkutsk', 'coord': (52.287054, 104.281047)}},
#  {'city1': {'name': 'Armavir', 'coord': (44.997655, 41.129644)},
#   'city2': {'name': 'Sochi', 'coord': (43.585525, 39.723062)}},
#  {'city1': {'name': 'Astrakhan', 'coord': (46.347869, 48.033574)},
#   'city2': {'name': 'Makhachkala', 'coord': (42.983059999999995, 47.504682)}},
#  {'city1': {'name': 'Balakovo',
#    'coord': (52.018423999999996, 47.819666999999995)},
#   'city2': {'name': 'Saratov',
#    'coord': (51.533103000000004, 46.03415800000001)}},
#  {'city1': {'name': 'Balashikha', 'coord': (55.796339, 37.938199)},
#   'city2': {'name': 'Lyubertsy',
#    'coord': (55.67649399999999, 37.898115999999995)}},
#  {'city1': {'name': 'Barnaul', 'coord': (53.346785, 83.77685600000002)},
#   'city2': {'name': 'Biysk', 'coord': (52.539297, 85.21382)}},
#  {'city1': {'name': 'Belgorod', 'coord': (50.595659999999995, 36.587223)},
#   'city2': {'name': 'Kursk', 'coord': (51.730361, 36.192646999999994)}},
#  {'city1': {'name': 'Blagoveshchensk', 'coord': (50.29064, 127.527173)},
#   'city2': {'name': 'Khabarovsk',
#    'coord': (48.480222999999995, 135.07191699999998)}},
#  {'city1': {'name': 'Angarsk', 'coord': (52.544357999999995, 103.88824)},
#   'city2': {'name': 'Bratsk', 'coord': (56.151362, 101.63408000000001)}},
#  {'city1': {'name': 'Bryansk', 'coord': (53.243562, 34.363407)},
#   'city2': {'name': 'Kaluga', 'coord': (54.513844999999996, 36.261215)}},
#  {'city1': {'name': 'Cheboksary', 'coord': (56.14627700000001, 47.251079)},
#   'city2': {'name': 'Yoshkar-Ola', 'coord': (56.631595, 47.886178)}},
#  {'city1': {'name': 'Chelyabinsk', 'coord': (55.159896999999994, 61.402554)},
#   'city2': {'name': 'Yekaterinburg', 'coord': (56.838011, 60.597465)}},
#  {'city1': {'name': 'Cherepovets', 'coord': (59.122612, 37.903461)},
#   'city2': {'name': 'Vologda', 'coord': (59.220496, 39.891523)}},
#  {'city1': {'name': 'Chita',
#    'coord': (52.033972999999996, 113.49943200000001)},
#   'city2': {'name': 'Ulan-Ude', 'coord': (51.834464000000004, 107.584574)}},
#  {'city1': {'name': 'Dzerzhinsk', 'coord': (56.238377, 43.461625)},
#   'city2': {'name': 'Ivanovo',
#    'coord': (57.000347999999995, 40.973921000000004)}},
#  {'city1': {'name': 'Ivanovo',
#    'coord': (57.000347999999995, 40.973921000000004)},
#   'city2': {'name': 'Kostroma', 'coord': (57.767961, 40.926858)}},
#  {'city1': {'name': 'Izhevsk',
#    'coord': (56.85259300000001, 53.204843000000004)},
#   'city2': {'name': 'Nizhnekamsk', 'coord': (55.634069999999994, 51.809112)}},
#  {'city1': {'name': 'Kaliningrad', 'coord': (54.707390000000004, 20.507307)},
#   'city2': {'name': 'Saint Petersburg',
#    'coord': (59.939094999999995, 30.315868)}},
#  {'city1': {'name': 'Kaluga', 'coord': (54.513844999999996, 36.261215)},
#   'city2': {'name': 'Tula', 'coord': (54.193121999999995, 37.617348)}},
#  {'city1': {'name': 'Kazan', 'coord': (55.796289, 49.108795)},
#   'city2': {'name': 'Yoshkar-Ola', 'coord': (56.631595, 47.886178)}},
#  {'city1': {'name': 'Kemerovo', 'coord': (55.354727000000004, 86.088374)},
#   'city2': {'name': 'Tomsk', 'coord': (56.48464, 84.947649)}},
#  {'city1': {'name': 'Khabarovsk',
#    'coord': (48.480222999999995, 135.07191699999998)},
#   'city2': {'name': 'Komsomolsk-on-Amur', 'coord': (50.549923, 137.007948)}},
#  {'city1': {'name': 'Khimki', 'coord': (55.88874000000001, 37.43039)},
#   'city2': {'name': 'Moscow', 'coord': (55.755814, 37.617635)}},
#  {'city1': {'name': 'Kirov', 'coord': (58.603591, 49.668014)},
#   'city2': {'name': 'Yoshkar-Ola', 'coord': (56.631595, 47.886178)}},
#  {'city1': {'name': 'Krasnodar', 'coord': (45.035470000000004, 38.975313)},
#   'city2': {'name': 'Novorossiysk', 'coord': (44.723912, 37.768974)}},
#  {'city1': {'name': 'Krasnoyarsk', 'coord': (56.010563, 92.852572)},
#   'city2': {'name': 'Novokuznetsk', 'coord': (53.757546999999995, 87.136044)}},
#  {'city1': {'name': 'Kurgan', 'coord': (55.44100400000001, 65.34111800000001)},
#   'city2': {'name': 'Tyumen', 'coord': (57.15303299999999, 65.534328)}},
#  {'city1': {'name': 'Lipetsk', 'coord': (52.608819999999994, 39.59922)},
#   'city2': {'name': 'Voronezh', 'coord': (51.660781, 39.200269)}},
#  {'city1': {'name': 'Magnitogorsk',
#    'coord': (53.407157999999995, 58.980281999999995)},
#   'city2': {'name': 'Orsk', 'coord': (51.229362, 58.475196)}},
#  {'city1': {'name': 'Moscow', 'coord': (55.755814, 37.617635)},
#   'city2': {'name': 'Mytishchi', 'coord': (55.910483, 37.73640200000001)}},
#  {'city1': {'name': 'Murmansk', 'coord': (68.970682, 33.074981)},
#   'city2': {'name': 'Petrozavodsk', 'coord': (61.785017, 34.346878000000004)}},
#  {'city1': {'name': 'Nizhnevartovsk',
#    'coord': (60.939716000000004, 76.56962800000002)},
#   'city2': {'name': 'Surgut', 'coord': (61.254034999999995, 73.396221)}},
#  {'city1': {'name': 'Kemerovo', 'coord': (55.354727000000004, 86.088374)},
#   'city2': {'name': 'Novokuznetsk', 'coord': (53.757546999999995, 87.136044)}},
#  {'city1': {'name': 'Barnaul', 'coord': (53.346785, 83.77685600000002)},
#   'city2': {'name': 'Novosibirsk',
#    'coord': (55.030198999999996, 82.92043000000002)}},
#  {'city1': {'name': 'Nizhnevartovsk',
#    'coord': (60.939716000000004, 76.56962800000002)},
#   'city2': {'name': 'Omsk', 'coord': (54.98934200000001, 73.368212)}},
#  {'city1': {'name': 'Orenburg', 'coord': (51.768198999999996, 55.096955)},
#   'city2': {'name': 'Sterlitamak', 'coord': (53.630403, 55.930825)}},
#  {'city1': {'name': 'Penza', 'coord': (53.195063, 45.018316)},
#   'city2': {'name': 'Saransk', 'coord': (54.187433, 45.183938)}},
#  {'city1': {'name': 'Izhevsk',
#    'coord': (56.85259300000001, 53.204843000000004)},
#   'city2': {'name': 'Perm', 'coord': (58.010374, 56.229397999999996)}},
#  {'city1': {'name': 'Petrozavodsk', 'coord': (61.785017, 34.346878000000004)},
#   'city2': {'name': 'Saint Petersburg',
#    'coord': (59.939094999999995, 30.315868)}},
#  {'city1': {'name': 'Samara', 'coord': (53.195538, 50.10178300000001)},
#   'city2': {'name': 'Ulyanovsk', 'coord': (54.31419200000001, 48.403123)}},
#  {'city1': {'name': 'Shakhty', 'coord': (47.709601, 40.215796999999995)},
#   'city2': {'name': 'Taganrog', 'coord': (47.220983000000004, 38.9173)}},
#  {'city1': {'name': 'Bryansk', 'coord': (53.243562, 34.363407)},
#   'city2': {'name': 'Smolensk', 'coord': (54.782635, 32.045251)}},
#  {'city1': {'name': 'Krasnodar', 'coord': (45.035470000000004, 38.975313)},
#   'city2': {'name': 'Sochi', 'coord': (43.585525, 39.723062)}},
#  {'city1': {'name': 'Sterlitamak', 'coord': (53.630403, 55.930825)},
#   'city2': {'name': 'Ufa', 'coord': (54.735147, 55.958727)}},
#  {'city1': {'name': 'Kirov', 'coord': (58.603591, 49.668014)},
#   'city2': {'name': 'Syktyvkar', 'coord': (61.66879300000001, 50.836399)}},
#  {'city1': {'name': 'Lipetsk', 'coord': (52.608819999999994, 39.59922)},
#   'city2': {'name': 'Tambov', 'coord': (52.721219, 41.452273999999996)}},
#  {'city1': {'name': 'Khimki', 'coord': (55.88874000000001, 37.43039)},
#   'city2': {'name': 'Tver', 'coord': (56.859846999999995, 35.91199500000001)}},
#  {'city1': {'name': 'Irkutsk', 'coord': (52.287054, 104.281047)},
#   'city2': {'name': 'Ulan-Ude', 'coord': (51.834464000000004, 107.584574)}},
#  {'city1': {'name': 'Kazan', 'coord': (55.796289, 49.108795)},
#   'city2': {'name': 'Ulyanovsk', 'coord': (54.31419200000001, 48.403123)}},
#  {'city1': {'name': 'Makhachkala', 'coord': (42.983059999999995, 47.504682)},
#   'city2': {'name': 'Vladikavkaz', 'coord': (43.02115, 44.68196)}},
#  {'city1': {'name': 'Ivanovo',
#    'coord': (57.000347999999995, 40.973921000000004)},
#   'city2': {'name': 'Vladimir',
#    'coord': (56.129056999999996, 40.406634999999994)}},
#  {'city1': {'name': 'Khabarovsk',
#    'coord': (48.480222999999995, 135.07191699999998)},
#   'city2': {'name': 'Vladivostok', 'coord': (43.115536, 131.88548500000002)}},
#  {'city1': {'name': 'Saratov',
#    'coord': (51.533103000000004, 46.03415800000001)},
#   'city2': {'name': 'Volgograd', 'coord': (48.707073, 44.51693)}},
#  {'city1': {'name': 'Blagoveshchensk', 'coord': (50.29064, 127.527173)},
#   'city2': {'name': 'Yakutsk', 'coord': (62.028082, 129.732609)}},
#  {'city1': {'name': 'Kostroma', 'coord': (57.767961, 40.926858)},
#   'city2': {'name': 'Yaroslavl', 'coord': (57.626578, 39.893858)}},
#  {'city1': {'name': 'Komsomolsk-on-Amur', 'coord': (50.549923, 137.007948)},
#   'city2': {'name': 'Yuzhno-Sakhalinsk',
#    'coord': (46.959154999999996, 142.738023)}},
#  {'city1': {'name': 'Bratsk', 'coord': (56.151362, 101.63408000000001)},
#   'city2': {'name': 'Krasnoyarsk', 'coord': (56.010563, 92.852572)}},
#  {'city1': {'name': 'Armavir', 'coord': (44.997655, 41.129644)},
#   'city2': {'name': 'Vladikavkaz', 'coord': (43.02115, 44.68196)}},
#  {'city1': {'name': 'Penza', 'coord': (53.195063, 45.018316)},
#   'city2': {'name': 'Saratov',
#    'coord': (51.533103000000004, 46.03415800000001)}},
#  {'city1': {'name': 'Balashikha', 'coord': (55.796339, 37.938199)},
#   'city2': {'name': 'Mytishchi', 'coord': (55.910483, 37.73640200000001)}},
#  {'city1': {'name': 'Biysk', 'coord': (52.539297, 85.21382)},
#   'city2': {'name': 'Novokuznetsk', 'coord': (53.757546999999995, 87.136044)}},
#  {'city1': {'name': 'Bryansk', 'coord': (53.243562, 34.363407)},
#   'city2': {'name': 'Kursk', 'coord': (51.730361, 36.192646999999994)}},
#  {'city1': {'name': 'Blagoveshchensk', 'coord': (50.29064, 127.527173)},
#   'city2': {'name': 'Chita',
#    'coord': (52.033972999999996, 113.49943200000001)}},
#  {'city1': {'name': 'Lyubertsy',
#    'coord': (55.67649399999999, 37.898115999999995)},
#   'city2': {'name': 'Tula', 'coord': (54.193121999999995, 37.617348)}},
#  {'city1': {'name': 'Kazan', 'coord': (55.796289, 49.108795)},
#   'city2': {'name': 'Nizhnekamsk', 'coord': (55.634069999999994, 51.809112)}},
#  {'city1': {'name': 'Chelyabinsk', 'coord': (55.159896999999994, 61.402554)},
#   'city2': {'name': 'Magnitogorsk',
#    'coord': (53.407157999999995, 58.980281999999995)}},
#  {'city1': {'name': 'Vologda', 'coord': (59.220496, 39.891523)},
#   'city2': {'name': 'Yaroslavl', 'coord': (57.626578, 39.893858)}},
#  {'city1': {'name': 'Krasnodar', 'coord': (45.035470000000004, 38.975313)},
#   'city2': {'name': 'Taganrog', 'coord': (47.220983000000004, 38.9173)}},
#  {'city1': {'name': 'Chelyabinsk', 'coord': (55.159896999999994, 61.402554)},
#   'city2': {'name': 'Kurgan',
#    'coord': (55.44100400000001, 65.34111800000001)}},
#  {'city1': {'name': 'Lipetsk', 'coord': (52.608819999999994, 39.59922)},
#   'city2': {'name': 'Tula', 'coord': (54.193121999999995, 37.617348)}},
#  {'city1': {'name': 'Cherepovets', 'coord': (59.122612, 37.903461)},
#   'city2': {'name': 'Petrozavodsk', 'coord': (61.785017, 34.346878000000004)}},
#  {'city1': {'name': 'Kurgan', 'coord': (55.44100400000001, 65.34111800000001)},
#   'city2': {'name': 'Omsk', 'coord': (54.98934200000001, 73.368212)}},
#  {'city1': {'name': 'Magnitogorsk',
#    'coord': (53.407157999999995, 58.980281999999995)},
#   'city2': {'name': 'Sterlitamak', 'coord': (53.630403, 55.930825)}},
#  {'city1': {'name': 'Nizhnevartovsk',
#    'coord': (60.939716000000004, 76.56962800000002)},
#   'city2': {'name': 'Novosibirsk',
#    'coord': (55.030198999999996, 82.92043000000002)}},
#  {'city1': {'name': 'Balashikha', 'coord': (55.796339, 37.938199)},
#   'city2': {'name': 'Vladimir',
#    'coord': (56.129056999999996, 40.406634999999994)}},
#  {'city1': {'name': 'Balakovo',
#    'coord': (52.018423999999996, 47.819666999999995)},
#   'city2': {'name': 'Ulyanovsk', 'coord': (54.31419200000001, 48.403123)}},
#  {'city1': {'name': 'Izhevsk',
#    'coord': (56.85259300000001, 53.204843000000004)},
#   'city2': {'name': 'Ufa', 'coord': (54.735147, 55.958727)}},
#  {'city1': {'name': 'Belgorod', 'coord': (50.595659999999995, 36.587223)},
#   'city2': {'name': 'Taganrog', 'coord': (47.220983000000004, 38.9173)}},
#  {'city1': {'name': 'Dzerzhinsk', 'coord': (56.238377, 43.461625)},
#   'city2': {'name': 'Saransk', 'coord': (54.187433, 45.183938)}}]

# %%
with open('../data/mst.json', 'w') as f:
    json.dump(e_json, f)
