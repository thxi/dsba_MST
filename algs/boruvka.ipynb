# %% [markdown]
# # Boruvka's alg

# %%
def find_root(root, i):
    # find returns the root of a tree with the element i
    if root[i] == i:
        return i
    return find_root(root, root[i])


def merge_trees(root, rank, x, y):
    # union unite the two sets based on their rank
    xroot = find_root(root, x)
    yroot = find_root(root, y)
    if rank[xroot] < rank[yroot]:
        root[xroot] = yroot
    elif rank[xroot] > rank[yroot]:
        root[yroot] = xroot
    else:
        root[yroot] = xroot
        rank[xroot] += 1


def boruvka(nodes, edges, cols):
    # nodes - the number of nodes in the graph
    # edges - the list of edges in the graph
    # each edge is a tuple(or a list) in the following format:
    # (node1(int), node2(int), distance(float))
    # cols - the list of the names of each node
    # example: nodes = 3, cols = ['A', 'B', 'C'] meaning that
    # node "0" is 'A'
    # node "1" is 'B'
    # node "2" is 'C'
    
    # returns the tree weight and 
    # the edges in the minimum spanning tree
    
    # list of spanning tree edges
    s_edges = list()
    # list of roots of nodes
    root = list(range(nodes))
    # list of ranks of nodes
    rank = [0] * nodes

    # initializing each node as its own component
    components = nodes

    # the weight of a minimum spanning tree
    tree_weight = 0.0

    while components > 1:
        # stores cheapest edge for each component
        cheapest = [-1.0] * nodes
        # finding the cheapest edge for every component
        for i in range(len(edges)):
            u, v, w = edges[i]
            root_u = find_root(root, u)
            root_v = find_root(root, v)

            if root_u != root_v:
                if cheapest[root_u] == -1 or cheapest[root_u][2] > w:
                    cheapest[root_u] = (u, v, w)

                if cheapest[root_v] == -1 or cheapest[root_v][2] > w:
                    cheapest[root_v] = (u, v, w)

        # Consider the above picked cheapest edges and add them
        # to MST
        for node in range(nodes):

            # Check if cheapest for current set exists
            if cheapest[node] != -1:
                u, v, w = cheapest[node]
                root_u = find_root(root, u)
                root_v = find_root(root, v)

                if root_u != root_v:
                    s_edges.append((cols[u], cols[v], w))
                    tree_weight += w
                    merge_trees(root, rank, root_u, root_v)
                    print("% s-%s % f" %
                          (cols[u], cols[v], w))
                    components = components - 1

        cheapest = [-1.0] * nodes

    print("Tree weight %f" % tree_weight)
    return (tree_weight, s_edges)

# %% [markdown]
# # Example

# %%
import pandas as pd
import numpy as np

# %%
mat = pd.read_csv("../data/example_mat.csv", index_col="name")

# %%
mat
# Out:
#         A    B    C    D    E    F
# name
# A     1.0  0.1 -1.0  0.4  0.3 -1.0
# B     0.1  1.0 -1.0  0.4  0.2 -1.0
# C    -1.0 -1.0  1.0 -1.0  0.4  0.5
# D     0.4  0.4 -1.0  1.0  0.4 -1.0
# E     0.3  0.2  0.4  0.4  1.0  0.7
# F    -1.0 -1.0  0.5 -1.0  0.7  1.0

# %% [markdown]
# <div><img width=200 src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Multiple_minimum_spanning_trees.svg/440px-Multiple_minimum_spanning_trees.svg.png"></div>

# %%
def read_mat(mat):
    # reads the graph
    # and returns the list of edges
    edges = list()
    for (i, (index, row)) in enumerate(mat.iterrows()):
        for (j, vert) in enumerate(mat.columns[i+1:]):
            if (row[vert] == -1):
                continue
            edges.append((i, j + i + 1, row[vert]))
    return edges

# %%
edges = read_mat(mat)

# %%
print(edges)
# Out:
# [(0, 1, 0.1), (0, 3, 0.4), (0, 4, 0.3), (1, 3, 0.4), (1, 4, 0.2), (2, 4, 0.4), (2, 5, 0.5), (3, 4, 0.4), (4, 5, 0.7)]

# %%
nodes = len(mat.columns)
cols = mat.columns

# %%
weight, s_edges = boruvka(nodes, edges, cols)
# Out:
# A-B  0.100000
# C-E  0.400000
# A-D  0.400000
# B-E  0.200000
# C-F  0.500000
# Tree weight 1.600000

# %%
print(weight, s_edges)
# Out:
# 1.6 [('A', 'B', 0.1), ('C', 'E', 0.4), ('A', 'D', 0.4), ('B', 'E', 0.2), ('C', 'F', 0.5)]

# %% [markdown]
# ### writing the result to file

# %%
import csv
def edges_to_csv(file_name, edges):
    with open('../data/'+file_name+'.csv', 'w') as csvfile:
        w = csv.writer(csvfile, delimiter=',')
        w.writerow(['node1', 'node2', 'dist'])
        for i in range(len(edges)):
            w.writerow(edges[i])

# %%
edges_to_csv('example_mst', s_edges)

# %% [markdown]
# # 'Real world' example

# %%
# mat = pd.read_csv("../data/ru_dist_mat_v1.csv")
mat = pd.read_csv("../data/ru_dist_mat_v1.csv", index_col="name")

nodes = len(mat.columns)
edges = read_mat(mat)
cols = mat.columns

# %%
weight, s_edges = boruvka(nodes, edges, cols)
# Out:
# Abakan-Chernogorsk  0.001852
# Abdulino-Priyutovo  0.003880
# Abinsk-Akhtyrskiy  0.001844
# Achinsk-Nazarovo  0.003181
# Achkhoy-Martan-Ordzhonikidzevskaya  0.003208
# Adler-Sochi  0.002648
# Afipskiy-Enem  0.000883
# Agidel’-Neftekamsk  0.003902
# Agryz-Izhevsk  0.004463
# Akademgorodok-Arsen’yev  0.000000
# Akhtubinsk-Znamensk  0.005754
# Aksay-Sorochinsk  0.013810
# Alagir-Ardon  0.001458
# Alapayevsk-Rezh  0.006619
# Alatyr’-Shumerlya  0.007922
# Aldan-Neryungri  0.024788
# Aleksandrov-Karabanovo  0.001048
# Aleksandrovsk-Kizel  0.001584
# Aleksandrovskoye-Zelenokumsk  0.000000
# Aleksin-Protvino  0.004556
# Aleysk-Barnaul  0.014216
# Altuf’yevskiy-Vostochnoe Degunino  0.000190
# Al’met’yevsk-Leninogorsk  0.003806
# Amursk-Komsomolsk-on-Amur  0.003526
# Anapa-Temryuk  0.003433
# Andreyevskoye-Istra  0.000397
# Angarsk-Usol’ye-Sibirskoye  0.003534
# Annino-Trubchevsk  0.001236
# Anzhero-Sudzhensk-Tayga  0.003778
# Apatity-Kirovsk  0.001858
# Aprelevka-Krasnoznamensk  0.000724
# Apsheronsk-Khadyzhensk  0.002514
# Aramil-Sysert’  0.002348
# Armavir-Novokubansk  0.001407
# Arsk-Kazan  0.008288
# Artëm-Vladivostok  0.004285
# Arzamas-Sarov  0.007179
# Arzgir-Budënnovsk  0.005182
# Asbest-Reftinskiy  0.002310
# Asha-Sim  0.004120
# Astrakhan-Kamyzyak  0.002208
# Atkarsk-Petrovsk  0.006368
# Avtury-Kurchaloy  0.001144
# Aykhal-Udachny  0.008860
# Azov-Levoberezhnyy  0.002870
# Babushkin-Gusinoozyorsk  0.008583
# Bagayevskaya-Novocherkassk  0.003581
# Bakal-Satka  0.002507
# Baksan-Dugulubgey  0.000190
# Balabanovo-Obninsk  0.001023
# Balakovo-Yershov  0.008709
# Balashikha-Reutov  0.000920
# Balashov-Yelan’  0.009051
# Balezino-Glazov  0.003708
# Barabinsk-Kupino  0.015480
# Barnaul-Novoaltaysk  0.001766
# Barysh-Kuznetsk  0.008040
# Bataysk-Rostov  0.000837
# Bavly-Tuymazy  0.005077
# Baymak-Sibay  0.004024
# Belaya Glina-Novopokrovskaya  0.002266
# Belaya Kalitva-Semikarakorsk  0.006298
# Belebey-Priyutovo  0.002973
# Belgorod-Razumnoye  0.001305
# Belidzhi-Derbent  0.002078
# Belogorsk-Blagoveshchensk  0.012337
# Akhtubinsk-Beloozërskiy  0.011352
# Belorechensk-Giaginskaya  0.002538
# Beloretsk-Magnitogorsk  0.008639
# Belovo-Polysayevo  0.002136
# Beloyarskiy-Nyagan  0.023678
# Berdsk-Krasnoobsk  0.002232
# Berezniki-Solikamsk  0.003134
# Beryozovsky-Kemerovo  0.004152
# Berëzovskiy-Yegorlykskaya  0.003730
# Beslan-Kantyshevo  0.001486
# Bezenchuk-Chapayevsk  0.002911
# Bezhetsk-Kashin  0.010073
# Bibirevo-Pereslavl’-Zalesskiy  0.001138
# Bikin-Luchegorsk  0.003470
# Birobidzhan-Vyazemskiy  0.024433
# Birsk-Dyurtyuli  0.006556
# Biryulëvo-Naro-Fominsk  0.001333
# Biysk-Mayma  0.009317
# Blagodarnyy-Divnoye  0.007396
# Bobrov-Liski  0.006020
# Bodaybo-Lensk  0.038021
# Bogdanovich-Sukhoy Log  0.001582
# Bogoroditsk-Uzlovaya  0.002387
# Bogorodsk-Noginsk  0.000000
# Bogorodskoye-Kirovo-Chepetsk  0.011293
# Bogotol-Sharypovo  0.008698
# Boguchar-Kalach  0.007191
# Boksitogorsk-Pikalëvo  0.002966
# Bologoye-Linëvo  0.003730
# Bolotnoye-Toguchin  0.005128
# Bol’shaya Setun’-Moskovskiy  0.001011
# Borisoglebsk-Gribanovskiy  0.001402
# Borodino-Zelenogorsk  0.003948
# Borovichi-Linëvo  0.005255
# Borzya-Nerchinsk  0.016850
# Bratsk-Vikhorevka  0.004524
# Bronnitsy-Zhukovskiy  0.002491
# Bryansk-Fokino  0.002439
# Bryukhovetskaya-Timashëvsk  0.001826
# Budënnovsk-Zelenokumsk  0.004761
# Akademgorodok-Bugul’ma  0.000000
# Buguruslan-Pokhvistnevo  0.003209
# Buinsk-Ulyanovsk  0.007600
# Buturlinovka-Kalach  0.006405
# Buynaksk-Kizilyurt  0.004458
# Buguruslan-Buzuluk  0.009783
# Chapayevsk-Nagornyy  0.000000
# Chaykovskiy-Votkinsk  0.003691
# Chebarkul’-Miass  0.002744
# Cheboksary-Zavolzh’ye  0.000438
# Chegem-Nal’chik  0.000596
# Chekhov-Serpukhov  0.002811
# Chelyabinsk-Kopeysk  0.002208
# Cheremkhovo-Usol’ye-Sibirskoye  0.007139
# Cherepanovo-Iskitim  0.004842
# Cherepovets-Veshnyaki  0.007146
# Cherkessk-Ust’-Dzheguta  0.001536
# Chernaya Rechka-Kolpashevo  0.014068
# Chernogolovka-Noginsk  0.001958
# Chernushka-Osa  0.011045
# Chernyakhovsk-Gusev  0.003883
# Chernyanka-Novyy Oskol  0.001980
# Chishmy-Yubileyny  0.000837
# Chistopol’-Kotlovka  0.008074
# Chita-Nerchinsk  0.033159
# Chudovo-Kirishi  0.005210
# Chunskiy-Vikhorevka  0.014651
# Chusovoy-Lys’va  0.002484
# Dagestanskiye Ogni-Derbent  0.001308
# Akademgorodok-Dal'negorsk  0.000000
# Akademgorodok-Dal’nerechensk  0.000000
# Danilov-Tutayev  0.007165
# Dankov-Lebedyan’  0.002518
# Davlekanovo-Rayevskiy  0.002068
# Dedovsk-Nakhabino  0.000671
# Degtyarsk-Revda  0.002108
# Desnogorsk-Roslavl’  0.004996
# Dinskaya-Pashkovskiy  0.002102
# Divnogorsk-Krasnoyarsk  0.004657
# Divnoye-Ipatovo  0.005529
# Dmitrov-Novogireyevo  0.002599
# Dobryanka-Perm  0.005979
# Akademgorodok-Dolgoprudnyy  0.000000
# Domodedovo-Vostryakovo  0.000937
# Donetsk-Rybatskoye  0.010340
# Donskoy-Novomoskovsk  0.000685
# Donskoye-Mikhaylovsk  0.002931
# Dubna-Kimry  0.002355
# Dubovka-Volzhskiy  0.002799
# Dudinka-Norilsk  0.012447
# Dyat’kovo-Fokino  0.001787
# Dzerzhinsk-Novaya Balakhna  0.003490
# Dzerzhinskiy-Kotel’niki  0.000369
# Ekazhevo-Nazran’  0.000707
# Elektrogorsk-Pavlovskiy Posad  0.001812
# Elektrostal’-Fryazevo  0.000705
# Elektrougli-Zyuzino  0.001072
# Arzgir-Elista  0.008504
# Enem-Oktyabr’skiy  0.000703
# Engel’s-Saratov  0.001104
# Ezhva-Syktyvkar  0.001977
# Frolovo-Mikhaylovka  0.005567
# Fryazino-Shchelkovo  0.000741
# Furmanov-Privolzhsk  0.002285
# Gagarin-Shatura  0.000353
# Galich-Kineshma  0.011815
# Gatchina-Krasnoye Selo  0.002166
# Gavrilov-Yam-Yaroslavl  0.004039
# Gay-Orsk  0.002528
# Abinsk-Gelendzhik  0.002786
# Georgiyevsk-Nezlobnaya  0.000862
# Giaginskaya-Maykop  0.002357
# Golitsyno-Krasnoznamensk  0.000576
# Gorelovo-Krasnoye Selo  0.000694
# Gorno-Altaysk-Mayma  0.000848
# Gornyak-Rubtsovsk  0.006053
# Gorodets-Novaya Balakhna  0.002114
# Gorodishche-Penza  0.007200
# Goryachevodskiy-Pyatigorsk  0.000357
# Goryachiy Klyuch-Pashkovskiy  0.003304
# Groznyy-Urus-Martan  0.002507
# Gryazi-Lipetsk  0.003979
# Gryazovets-Vologda  0.005472
# Gubakha-Kizel  0.002867
# Chernyanka-Gubkin  0.004713
# Gubkinskiy-Tarko-Sale  0.011651
# Gudermes-Kurchaloy  0.001220
# Gukovo-Krasnyy Sulin  0.002090
# Akademgorodok-Gul’kevichi  0.000000
# Gus’-Khrustal’nyy-Vladimir  0.006590
# Balezino-Igra  0.005484
# Ilanskiy-Kansk  0.003518
# Inozemtsevo-Pyatigorsk  0.000542
# Barysh-Inza  0.008246
# Ipatovo-Svetlograd  0.003508
# Irbit-Turinsk  0.007439
# Irkutsk-Shelekhov  0.002133
# Isakogorka-Novodvinsk  0.001587
# Ishim-Zavodoukovsk  0.028916
# Ishimbay-Salavat  0.001622
# Berdsk-Iskitim  0.002417
# Ivanovo-Kokhma  0.001407
# Ivanovskoye-Krasnogorsk  0.000366
# Ivanteyevka-Pushkino  0.000891
# Ivdel’-Krasnotur’insk  0.012372
# Izberbash-Kaspiysk  0.004003
# Izluchinsk-Nizhnevartovsk  0.002731
# Izmaylovo-Mtsensk  0.004225
# Akademgorodok-Izobil’nyy  0.000000
# Kabanovo-Uglich  0.001651
# Kachkanar-Lesnoy  0.002991
# Kalach-na-Donu-Surovikino  0.008036
# Kalachinsk-Omsk  0.012162
# Kaliningrad-Mikhalkovo  0.009185
# Kalininsk-Zhirnovsk  0.006370
# Kalininskiy-Yablonovskiy  0.005884
# Kaltan-Osinniki  0.001075
# Kaluga-Kondrovo  0.004807
# Kamensk-Shakhtinskiy-Zverevo  0.003295
# Bogdanovich-Kamensk-Ural’skiy  0.004556
# Kamen’-na-Obi-Suzun  0.009914
# Kamyshin-Kotovo  0.007210
# Bogdanovich-Kamyshlov  0.006422
# Kanash-Novocheboksarsk  0.007223
# Kandalaksha-Polyarnyye Zori  0.003242
# Bryukhovetskaya-Kanevskaya  0.002574
# Kantyshevo-Nazran’  0.001478
# Karabash-Kyshtym  0.004203
# Karabulak-Surkhakhi  0.000991
# Karachayevsk-Ust’-Dzheguta  0.002713
# Bryansk-Karachev  0.006617
# Karasuk-Slavgorod  0.010337
# Karpinsk-Krasnotur’insk  0.001690
# Kartaly-Plast  0.015068
# Kashin-Kimry  0.006434
# Kashira-Luzhniki  0.000367
# Kasimov-Melenki  0.005314
# Kasli-Ozersk  0.001661
# Kaspiysk-Makhachkala  0.001834
# Katav-Ivanovsk-Ust’-Katav  0.002095
# Kamensk-Ural’skiy-Kataysk  0.006622
# Kavalerovo-Luchegorsk  0.021751
# Kazan-Zelenodolsk  0.005995
# Kedrovka-Kushva  0.003873
# Khabarovsk-Khabarovsk Vtoroy  0.007592
# Khanty-Mansiysk-Poykovskiy  0.024397
# Astrakhan-Kharabali  0.013670
# Khasavyurt-Kizilyurt  0.003536
# Khimki-Krasnogorsk  0.001199
# Kholmsk-Lyublino  0.001294
# Khot'kovo-Sofrino  0.001510
# Donskoy-Kimovsk  0.002011
# Kinel’-Samara  0.005574
# Kineshma-Sokol’niki  0.000386
# Kireyevsk-Uzlovaya  0.002432
# Kirov-Rublëvo  0.002545
# Kirovgrad-Novoural’sk  0.002314
# Kirovo-Chepetsk-Slobodskoy  0.002569
# Kirsanov-Uvarovo  0.008805
# Karabanovo-Kirzhach  0.002451
# Belovo-Kiselëvsk  0.005851
# Kislovodsk-Yessentuki  0.002137
# Khasavyurt-Kizlyar  0.005240
# Klimovsk-Syktyvkar  0.024025
# Klin-Solnechnogorsk  0.002990
# Kochubeyevskoye-Nevinnomyssk  0.001460
# Chunskiy-Kodinsk  0.031929
# Kogalym-Pokachi  0.011570
# Kolomna-Voskresensk  0.002710
# Kolpino-Metallostroy  0.000795
# Komendantsky aerodrom-Saint Petersburg  0.000871
# Kommunar-Pavlovsk  0.000907
# Dubna-Konakovo  0.003789
# Kondopoga-Petrozavodsk  0.005732
# Konstantinovsk-Semikarakorsk  0.003406
# Korenovsk-Vyselki  0.002743
# Korkino-Yemanzhelinsk  0.001804
# Ivanteyevka-Korolev  0.000903
# Korsakov-Yuzhno-Sakhalinsk  0.003061
# Koryazhma-Kotlas  0.004494
# Kostomuksha-Segezha  0.030570
# Kostroma-Volgorechensk  0.004614
# Akademgorodok-Kotel’nich  0.000000
# Kotel’nikovo-Nizhniy Lomov  0.004280
# Kotlovka-Nurlat  0.003387
# Kotovo-Zhirnovsk  0.006890
# Kovdor-Polyarnyye Zori  0.013863
# Kovrov-Shuya  0.006002
# Kovylkino-Nizhniy Lomov  0.006297
# Kozhukhovo-Udomlya  0.006458
# Krasnoarmeysk-Privolzhskiy  0.005649
# Krasnoarmeyskaya-Zimovniki  0.008786
# Krasnodar-Oktyabr’skiy  0.000618
# Krasnogvardeyskoye-Valuyki  0.005618
# Borzya-Krasnokamensk  0.017101
# Krasnokamsk-Nytva  0.004153
# Krasnoobsk-Novosibirsk  0.001460
# Krasnoufimsk-Kungur  0.012736
# Krasnoural’sk-Kushva  0.002816
# Krasnovishersk-Solikamsk  0.010338
# Krasnyy Sulin-Zverevo  0.001496
# Kronshtadt-Lomonosov  0.001019
# Kropotkin-Tbilisskaya  0.004627
# Abinsk-Krymsk  0.002126
# Kstovo-Sovetskiy  0.002421
# Kubinka-Setun’  0.000886
# Kudymkar-Vereshchagino  0.011814
# Kukmor-Vyatskiye Polyany  0.001810
# Kulebaki-Navashino  0.003477
# Kulunda-Yarovoye  0.005550
# Kumertau-Meleuz  0.002641
# Kungur-Perm  0.009878
# Karasuk-Kupino  0.010547
# Kurgan-Tsaritsyno  0.002682
# Kurganinsk-Labinsk  0.002731
# Kurovskoye-Likino-Dulevo  0.001574
# Kursk-Solntsevo  0.006956
# Kurtamysh-Tsaritsyno  0.009113
# Kuskovo-Tomsk  0.003338
# Kuvandyk-Mednogorsk  0.002543
# Kuybyshev-Samara  0.000000
# Gusinoozyorsk-Kyakhta  0.009732
# Kyshtym-Ozersk  0.001783
# Kyzyl-Shushenskoye  0.032046
# Labinsk-Mostovskoy  0.002062
# Labytnangi-Salekhard  0.002498
# Lakinsk-Sobinka  0.000666
# Langepas-Pokachi  0.007415
# Leningradskaya-Starominskaya  0.004527
# Leninsk-Volzhskiy  0.005232
# Leninsk-Kuznetsky-Polysayevo  0.001375
# Lensk-Mirny  0.026096
# Lermontov-Zheleznovodsk  0.000753
# Lesnoy-Nizhnyaya Tura  0.000491
# Lesosibirsk-Yeniseysk  0.004211
# Lesozavodsk-Luchegorsk  0.013848
# Konakovo-Levoberezhnaya  0.003938
# Bataysk-Levoberezhnyy  0.002166
# Likino-Dulevo-Orekhovo-Zuyevo  0.001193
# Liski-Novovoronezh  0.004598
# Livny-Shchigry  0.009534
# Khimki-Lobnya  0.001544
# Lodeynoye Pole-Tikhvin  0.014255
# Losino-Petrovskiy-Monino  0.000397
# Lukhovitsy-Zaraysk  0.002859
# Lyantor-Nefteyugansk  0.008111
# Lyskovo-Sergach  0.007360
# Dzerzhinskiy-Lytkarino  0.000848
# Kotel’niki-Lyubertsy  0.000397
# Dyat’kovo-Lyudinovo  0.003236
# Magadan-Okha  0.101770
# Magnitogorsk-Sibay  0.008299
# Malakhovka-Tomilino  0.000634
# Malgobek-Staryy Malgobek  0.000000
# Maloyaroslavets-Obninsk  0.001708
# Manturovo-Semënov  0.014342
# Beryozovsky-Mariinsk  0.015763
# Markova-Starominskaya  0.002377
# Engel’s-Marks  0.007094
# Mar’ina Roshcha-Moscow  0.000492
# Matveyevskoye-Tver  0.004330
# Medvedevo-Podol’sk  0.007913
# Medvedovskaya-Timashëvsk  0.001745
# Akademgorodok-Medvezh’yegorsk  0.000000
# Megion-Nizhnevartovsk  0.004143
# Melenki-Murom  0.005031
# Mendeleyevsk-Naberezhnyye Chelny  0.002051
# Menzelinsk-Naberezhnyye Chelny  0.006836
# Mezhdurechensk-Myski  0.002750
# Gryazi-Michurinsk  0.007242
# Chernyakhovsk-Mikhalkovo  0.006360
# Mikhaylovsk-Stavropol’  0.001047
# Kamensk-Shakhtinskiy-Millerovo  0.006112
# Inozemtsevo-Mineralnye Vody  0.001127
# Abakan-Minusinsk  0.002532
# Monchegorsk-Olenegorsk  0.003728
# Monino-Staraya Kupavna  0.000393
# Morozovsk-Tsimlyansk  0.007402
# Morshansk-Rasskazovo  0.008782
# Moscow-Moskovskiy  0.000741
# Malgobek-Mozdok  0.002045
# Mozhaysk-Tuchkovo  0.003999
# Mendeleyevsk-Mozhga  0.006688
# Muravlenko-Noyabrsk  0.011123
# Murmansk-Severomorsk  0.002657
# Murom-Navashino  0.001409
# Korolev-Mytishchi  0.001165
# Muravlenko-Nadym  0.029020
# Nakhodka-Partizansk  0.003804
# Nar'yan-Mar-Yegor’yevsk  0.032431
# Nartkala-Prokhladnyy  0.002518
# Neftegorsk-Otradnyy  0.006774
# Mozdok-Neftekumsk  0.009539
# Nefteyugansk-Pyt-Yakh  0.004782
# Nelidovo-Ostashkov  0.011729
# Kostroma-Nerekhta  0.005111
# Neryungri-Tynda  0.017860
# Nesterovskaya-Nyandoma  0.005576
# Nevel’-Velikiye Luki  0.007069
# Lyublino-Nevel’sk  0.002907
# Nikel’-Zapolyarnyy  0.003755
# Kurtamysh-Nikolayevsk  0.020833
# Nikulino-Sofrino  0.001334
# Nizhnekamsk-Yelabuga  0.002822
# Lyantor-Nizhnesortymskiy  0.011596
# Chunskiy-Nizhneudinsk  0.015295
# Nizhniy Novgorod-Sovetskiy  0.000462
# Kushva-Nizhniy Tagil  0.005080
# Nizhnyaya Salda-Verkhnyaya Salda  0.001399
# Novaya Usman’-Voronezh  0.002309
# Novoanninskiy-Uryupinsk  0.007749
# Cheboksary-Novocheboksarsk  0.002262
# Novocherkassk-Shakhty  0.003095
# Novogireyevo-Semënovskoye  0.002159
# Kuybyshev-Novokuybyshevsk  0.001936
# Novokuznetsk-Osinniki  0.002747
# Novomichurinsk-Skopin  0.003171
# Georgiyevsk-Novopavlovsk  0.002553
# Krymsk-Novorossiysk  0.003249
# Krasnyy Sulin-Novoshakhtinsk  0.001973
# Novotitarovskaya-Yasenevo  0.000524
# Novotroitsk-Orsk  0.001928
# Akademgorodok-Novoul’yanovsk  0.000000
# Novouzensk-Yershov  0.009520
# Novovoronezh-Voronezh  0.003770
# Novozybkov-Unecha  0.008524
# Novyy Urengoy-Tarko-Sale  0.018572
# Nyagan-Yugorsk  0.020763
# Novosibirsk-Ob’  0.002306
# Odintsovo-Vnukovo  0.000883
# Okha-Severo-Zadonsk  0.038848
# Glazov-Omutninsk  0.008055
# Onega-Severodvinsk  0.016058
# Karabulak-Ordzhonikidzevskaya  0.001760
# Akademgorodok-Orekhovo-Borisovo  0.000000
# Orenburg-Sol’-Iletsk  0.006571
# Orlovskiy-Proletarsk  0.004190
# Mtsensk-Orël  0.006357
# Nytva-Osa  0.008281
# Ostashkov-Valday  0.010530
# Liski-Ostrogozhsk  0.004752
# Otradnaya-Zelenchukskaya  0.004560
# Kolpino-Otradnoye  0.001762
# Ilanskiy-Ozerki  0.004378
# Ozëry-Zaraysk  0.003364
# Novouzensk-Pallasovka  0.014585
# Krasnodar-Pashkovskiy  0.001962
# Dzerzhinsk-Pavlovo  0.005083
# Pavlovsk-Pushkin  0.000487
# Pavlovskaya-Tikhoretsk  0.004757
# Pechora-Usinsk  0.012426
# Krasnokamsk-Perm  0.004632
# Azov-Persianovka  0.003896
# Pervoural’sk-Revda  0.001335
# Kozhukhovo-Pestovo  0.007216
# Peterhof-Petrodvorets  0.000000
# Petropavlovsk-Kamchatsky-Vilyuchinsk  0.002702
# Akademgorodok-Petrovsk-Zabaykal’skiy  0.000000
# Petrovskaya-Slavyansk-na-Kubani  0.002541
# Petushki-Pokrov  0.002807
# Plast-Yemanzhelinsk  0.006855
# Plavsk-Tula  0.006495
# Pochep-Trubchevsk  0.005073
# Orekhovo-Zuyevo-Pokrov  0.002300
# Degtyarsk-Polevskoy  0.003179
# Polyarnyy-Severomorsk  0.001937
# Poronaysk-Yuzhno-Sakhalinsk  0.021858
# Borisoglebsk-Povorino  0.002644
# Nefteyugansk-Poykovskiy  0.006153
# Petrovskaya-Primorsko-Akhtarsk  0.006121
# Priozërsk-Sortavala  0.010192
# Privolzhsk-Volgorechensk  0.001370
# Engel’s-Privolzhskiy  0.001175
# Promyshlennaya-Topki  0.004241
# Protvino-Serpukhov  0.002054
# Pugachev-Yershov  0.008988
# Pushchino-Serpukhov  0.002259
# Pyatigorsk-Svobody  0.000272
# Pokachi-Raduzhny  0.016231
# Ramenki-Rybnoye  0.001354
# Rasskazovo-Tambov  0.004528
# Belogorsk-Raychikhinsk  0.015549
# Reftinskiy-Rezh  0.004398
# Rodniki-Vichuga  0.002214
# Roshal’-Shatura  0.003188
# Liski-Rossosh’  0.008276
# Rostokino-Strunino  0.000656
# Rostov-Rostov-na-Donu  0.000000
# Rtishchevo-Serdobsk  0.004951
# Ruzayevka-Saransk  0.002823
# Ryazanskiy-Ryazan’  0.000000
# Novomichurinsk-Ryazhsk  0.004896
# Rybatskoye-Yeysk  0.010202
# Rybinsk-Sheksna  0.000000
# Rzhev-Torzhok  0.011295
# Safonovo-Yartsevo  0.005493
# Kuvandyk-Saraktash  0.011289
# Chaykovskiy-Sarapul  0.005066
# Kasimov-Sasovo  0.008658
# Sayanogorsk-Shushenskoye  0.006186
# Sayansk-Zima  0.002552
# Kondopoga-Segezha  0.021464
# Semiluki-Voronezh  0.001997
# Gorodets-Semënov  0.009807
# Khot'kovo-Sergiyev Posad  0.001704
# Krasnotur’insk-Serov  0.003929
# Komendantsky aerodrom-Sertolovo  0.001934
# Kronshtadt-Sestroretsk  0.002093
# Komsomolsk-on-Amur-Severo-Zadonsk  0.036549
# Akademgorodok-Severobaykal’sk  0.000000
# Isakogorka-Severodvinsk  0.006244
# Akademgorodok-Severoural’sk  0.000000
# Seversk-Tomsk  0.001576
# Afipskiy-Severskaya  0.002015
# Kataysk-Shadrinsk  0.010423
# Krasnyy Sulin-Shakhty  0.002560
# Avtury-Shali  0.001306
# Sharypovo-Uzhur  0.007060
# Shcherbinka-Vidnoye  0.001547
# Shchigry-Solntsevo  0.005204
# Shchukino-Tutayev  0.003092
# Shchëkino-Zheleznogorsk  0.012509
# Razumnoye-Shebekino  0.002497
# Belogorsk-Shimanovsk  0.014509
# Shadrinsk-Shumikha  0.010707
# Pushkin-Shushary  0.001153
# Minusinsk-Shushenskoye  0.005088
# Kokhma-Shuya  0.002955
# Skhodnya-Zelenograd  0.000724
# Slavgorod-Yarovoye  0.001164
# Shelekhov-Slyudyanka  0.007220
# Smolensk-Yartsevo  0.007286
# Kasli-Snezhinsk  0.002318
# Sokol-Vologda  0.003613
# Buzuluk-Sorochinsk  0.010198
# Sosnogorsk-Ukhta  0.001579
# Sertolovo-Sosnovaya Polyana  0.002959
# Sosnovka-Vyatskiye Polyany  0.002055
# Krasnoyarsk-Sosnovoborsk  0.004888
# Chernyakhovsk-Sovetsk  0.005316
# Lyublino-Sovetskaya Gavan’  0.027749
# Akademgorodok-Spassk-Dal’niy  0.000000
# Sredneuralsk-Verkhnyaya Pyshma  0.001017
# Staraya Russa-Velikiy Novgorod  0.006743
# Starodub-Unecha  0.003028
# Starominskaya-Staroshcherbinovskaya  0.004721
# Staryy Oskol-Valuyki  0.008212
# Ishimbay-Sterlitamak  0.002308
# Izluchinsk-Strezhevoy  0.006727
# Strogino-Tuchkovo  0.002036
# Belgorod-Stroitel’  0.002257
# Luzhniki-Stupino  0.000625
# Lyudinovo-Sukhinichi  0.009553
# Nefteyugansk-Surgut  0.006933
# Kaluga-Suvorov  0.005067
# Kislovodsk-Suvorovskaya  0.002611
# Rostokino-Sviblovo  0.001501
# Bezenchuk-Syzran’  0.010241
# Markova-Taganrog  0.005425
# Fryazevo-Taganskiy  0.001170
# Kamyshlov-Talitsa  0.009930
# Akademgorodok-Tal’menka  0.000000
# Kalachinsk-Tara  0.022511
# Kaltan-Tashtagol  0.010315
# Kalachinsk-Tatarsk  0.014030
# Tavda-Tyumen  0.011272
# Tayga-Yashkino  0.002986
# Nizhneudinsk-Tayshet  0.016023
# Tbilisskaya-Tikhoretsk  0.004484
# Prokhladnyy-Terek  0.002810
# Ivanovo-Teykovo  0.004540
# Boksitogorsk-Tikhvin  0.003496
# Lyubertsy-Tomilino  0.000534
# Torzhok-Vyshniy Volochëk  0.007772
# Otradnoye-Tosno  0.003118
# Troitsk-Vnukovo  0.001474
# Tsimlyansk-Volgodonsk  0.001758
# Akademgorodok-Tsotsin-Yurt  0.000000
# Goryachiy Klyuch-Tuapse  0.004641
# Tula-Yasnogorsk  0.003387
# Nizhneudinsk-Tulun  0.016165
# Kotel’nikovo-Tyoply Stan  0.008233
# Kislovodsk-Tyrnyauz  0.004927
# Tyumen-Yalutorovsk  0.009581
# Satka-Uchaly  0.009056
# Kislovodsk-Uchkeken  0.002547
# Udomlya-Vyshniy Volochëk  0.005491
# Ufa-Yubileyny  0.005248
# Gusinoozyorsk-Ulan-Ude  0.012905
# Uray-Yugorsk  0.020033
# Povorino-Uryupinsk  0.004824
# Gryazi-Usman’  0.005455
# Artëm-Ussuriysk  0.004728
# Ust’-Ilimsk-Zheleznogorsk-Ilimskiy  0.021051
# Ust’-Kut-Zheleznogorsk-Ilimskiy  0.016111
# Ust’-Labinsk-Vyselki  0.003281
# Gribanovskiy-Uvarovo  0.006449
# Novomoskovsk-Uzlovaya  0.001390
# Linëvo-Valday  0.004076
# Akademgorodok-Vasil’yevo  0.000000
# Vasyl'evsky Ostrov-Vsevolozhsk  0.002620
# Kotlas-Velikiy Ustyug  0.007122
# Venëv-Yasnogorsk  0.003843
# Nytva-Vereshchagino  0.006450
# Polevskoy-Verkhniy Ufaley  0.004818
# Veshnyaki-Zyablikovo  0.004673
# Domodedovo-Vidnoye  0.001541
# Kantyshevo-Vladikavkaz  0.001737
# Sobinka-Vladimir  0.004124
# Volgograd-Volzhskiy  0.002815
# Kirishi-Volkhov  0.006614
# Strogino-Volokolamsk  0.005123
# Volzhsk-Zelenodolsk  0.001273
# Vorgashor-Vorkuta  0.002171
# Bikin-Vyazemskiy  0.009015
# Murom-Vyazniki  0.008094
# Akademgorodok-Vyaz’ma  0.000000
# Navashino-Vyksa  0.002646
# Aldan-Yakutsk  0.059552
# Yalutorovsk-Zavodoukovsk  0.002810
# Neftekamsk-Yanaul  0.006960
# Yaransk-Yoshkar-Ola  0.008220
# Shchukino-Yaroslavl  0.003835
# Ussuriysk-Yaroslavskiy  0.004750
# Yefremov-Yelets  0.006978
# Sosnogorsk-Yegor’yevsk  0.026310
# Verkhnyaya Pyshma-Yekaterinburg  0.001588
# Afipskiy-Yelizavetinskaya  0.001365
# Vilyuchinsk-Yelizovo  0.003089
# Ezhva-Yemva  0.011070
# Yessentuki-Yessentukskaya  0.000266
# Staroshcherbinovskaya-Yeysk  0.004744
# Novocheboksarsk-Yoshkar-Ola  0.007463
# Yashkino-Yurga  0.005288
# Akademgorodok-Yuzhnoural’sk  0.000000
# Nizhnekamsk-Zainsk  0.004415
# Novoaltaysk-Zarinsk  0.010905
# Karachayevsk-Zelenchukskaya  0.004240
# Bagayevskaya-Zernograd  0.004393
# Shimanovsk-Zeya  0.019946
# Karachev-Zheleznogorsk  0.009545
# Gribanovskiy-Zherdevka  0.006989
# Bezenchuk-Zhigulevsk  0.004726
# Dyat’kovo-Zhukovka  0.006333
# Zhukovskiy-Zyuzino  0.000967
# Volgodonsk-Zimovniki  0.004723
# Miass-Zlatoust  0.004599
# Golitsyno-Zvenigorod  0.001876
# Chernogorsk-Uzhur  0.022946
# Belebey-Tuymazy  0.007138
# Krymsk-Slavyansk-na-Kubani  0.003351
# Bogotol-Nazarovo  0.008941
# Khadyzhensk-Sochi  0.007375
# Krasnodar-Yasenevo  0.001327
# Neftekamsk-Sarapul  0.006245
# Izhevsk-Sarapul  0.007448
# Akademgorodok-Krasnokamensk  0.021136
# Leninsk-Znamensk  0.006291
# Ardon-Beslan  0.003035
# Sergach-Shumerlya  0.009258
# Tynda-Zeya  0.030323
# Karabanovo-Strunino  0.001375
# Chusovoy-Gubakha  0.007286
# Pushchino-Yasnogorsk  0.004148
# Cherepanovo-Novoaltaysk  0.010873
# Mar’ina Roshcha-Vostochnoe Degunino  0.000917
# Al’met’yevsk-Zainsk  0.005509
# Amursk-Khabarovsk  0.027027
# Anapa-Novorossiysk  0.005795
# Istra-Zvenigorod  0.002203
# Angarsk-Shelekhov  0.004275
# Pochep-Zhukovka  0.007390
# Bolotnoye-Yurga  0.005418
# Apatity-Monchegorsk  0.006364
# Setun’-Zvenigorod  0.002092
# Apsheronsk-Belorechensk  0.003031
# Aramil-Yekaterinburg  0.002866
# Labinsk-Novokubansk  0.005690
# Novocheboksarsk-Volzhsk  0.009199
# Artëm-Nakhodka  0.009969
# Arzamas-Kstovo  0.009933
# Aleksandrovskoye-Novopavlovsk  0.004910
# Reftinskiy-Sukhoy Log  0.004118
# Sim-Ust’-Katav  0.004907
# Akhtubinsk-Kharabali  0.015187
# Atkarsk-Kalininsk  0.006855
# Groznyy-Shali  0.002956
# Aykhal-Mirny  0.050968
# Babushkin-Irkutsk  0.018057
# Bakal-Ust’-Katav  0.006362
# Chegem-Dugulubgey  0.000975
# Balabanovo-Naro-Fominsk  0.002630
# Balakovo-Marks  0.012077
# Lyubertsy-Reutov  0.001087
# Kalininsk-Yelan’  0.010038
# Igra-Izhevsk  0.008520
# Gorodishche-Inza  0.009454
# Azov-Markova  0.004595
# Berëzovskiy-Novopokrovskaya  0.004311
# Bagayevskaya-Semikarakorsk  0.005422
# Solntsevo-Stroitel’  0.007259
# Dagestanskiye Ogni-Izberbash  0.005497
# Beloretsk-Katav-Ivanovsk  0.009340
# Kiselëvsk-Novokuznetsk  0.005858
# Ivdel’-Yugorsk  0.026059
# Aleksandrovsk-Berezniki  0.007651
# Kemerovo-Topki  0.004788
# Ekazhevo-Surkhakhi  0.001083
# Nagornyy-Novokuybyshevsk  0.002816
# Dubna-Novogireyevo  0.004123
# Aleksandrov-Bibirevo  0.003482
# Khabarovsk Vtoroy-Vyazemskiy  0.009164
# Birsk-Ufa  0.009042
# Biryulëvo-Kubinka  0.001701
# Biysk-Zarinsk  0.013466
# Blagodarnyy-Zelenokumsk  0.008097
# Novaya Usman’-Usman’  0.005556
# Bogorodsk-Elektrostal’  0.000837
# Kirov-Kirovo-Chepetsk  0.003471
# Bobrov-Buturlinovka  0.006631
# Tikhvin-Volkhov  0.010983
# Bologoye-Vyshniy Volochëk  0.005990
# Mikhaylovka-Novoanninskiy  0.007975
# Borodino-Kansk  0.008624
# Tulun-Zima  0.016643
# Malakhovka-Zyuzino  0.001179
# Medvedovskaya-Novotitarovskaya  0.001910
# Otradnyy-Pokhvistnevo  0.008624
# Buinsk-Kanash  0.010225
# Buynaksk-Makhachkala  0.005142
# Karabash-Miass  0.005309
# Chelyabinsk-Korkino  0.003130
# Pestovo-Zyablikovo  0.008618
# Cherkessk-Nevinnomyssk  0.003793
# Chernaya Rechka-Seversk  0.014246
# Gusev-Nevel’  0.078901
# Krasnogvardeyskoye-Novyy Oskol  0.006040
# Chishmy-Davlekanovo  0.005509
# Chistopol’-Kukmor  0.010071
# Chudovo-Velikiy Novgorod  0.008432
# Rybinsk-Tutayev  0.006616
# Lebedyan’-Lipetsk  0.006705
# Ivanovskoye-Nakhabino  0.001178
# Novoural’sk-Pervoural’sk  0.004432
# Desnogorsk-Zhukovka  0.008374
# Sosnovoborsk-Zelenogorsk  0.012197
# Dmitrov-Lobnya  0.004012
# Dzerzhinskiy-Vidnoye  0.001643
# Uzlovaya-Venëv  0.004321
# Nevinnomyssk-Stavropol’  0.003562
# Dudinka-Novyy Urengoy  0.079067
# Nizhniy Novgorod-Novaya Balakhna  0.004451
# Fryazevo-Pavlovskiy Posad  0.001898
# Krasnoarmeysk-Zhirnovsk  0.010072
# Ukhta-Yemva  0.025741
# Ivanteyevka-Shchelkovo  0.000896
# Furmanov-Ivanovo  0.003344
# Gagarin-Petushki  0.004219
# Sokol’niki-Vichuga  0.003285
# Gorelovo-Shushary  0.002103
# Mednogorsk-Novotroitsk  0.008137
# Baksan-Novopavlovsk  0.002616
# Aleysk-Rubtsovsk  0.019915
# Inozemtsevo-Zheleznovodsk  0.000796
# Danilov-Gryazovets  0.008793
# Gubkinskiy-Muravlenko  0.017780
# Novocherkassk-Rostov  0.004799
# Irbit-Talitsa  0.010423
# Onega-Segezha  0.029129
# Meleuz-Salavat  0.004514
# Nizhnyaya Tura-Serov  0.014026
# Langepas-Megion  0.008302
# Izmaylovo-Plavsk  0.008673
# Kabanovo-Rybinsk  0.006772
# Krasnoural’sk-Nizhnyaya Tura  0.003985
# Frolovo-Kalach-na-Donu  0.010834
# Kupino-Tatarsk  0.016652
# Morozovsk-Yablonovskiy  0.010483
# Myski-Osinniki  0.005014
# Kondrovo-Maloyaroslavets  0.005889
# Cherepanovo-Suzun  0.011914
# Apatity-Polyarnyye Zori  0.006763
# Snezhinsk-Verkhniy Ufaley  0.004896
# Kashira-Ozëry  0.004110
# Kovrov-Vyazniki  0.008323
# Kholmsk-Yuzhno-Sakhalinsk  0.008321
# Pushkino-Sofrino  0.001689
# Lermontov-Yessentukskaya  0.001383
# Andreyevskoye-Solnechnogorsk  0.003062
# Kolomna-Lukhovitsy  0.003167
# Kolpino-Pushkin  0.001626
# Saint Petersburg-Shushary  0.001809
# Lodeynoye Pole-Petrozavodsk  0.015675
# Dinskaya-Korenovsk  0.003479
# Ezhva-Koryazhma  0.030250
# Sasovo-Tyoply Stan  0.008733
# Dobryanka-Gubakha  0.011471
# Lomonosov-Peterhof  0.001208
# Giaginskaya-Tbilisskaya  0.004642
# Nizhnekamsk-Sosnovka  0.009054
# Kurtamysh-Shumikha  0.012028
# Kropotkin-Kurganinsk  0.004782
# Elektrogorsk-Orekhovo-Zuyevo  0.002125
# Kuskovo-Tayga  0.007999
# Labytnangi-Vorkuta  0.020124
# Roshal’-Sobinka  0.004240
# Kanevskaya-Starominskaya  0.004222
# Lesosibirsk-Sosnovoborsk  0.026760
# Elektrougli-Staraya Kupavna  0.001200
# Langepas-Surgut  0.014978
# Kstovo-Lyskovo  0.008266
# Kantyshevo-Staryy Malgobek  0.002426
# Levoberezhnaya-Tver  0.004563
# Medvedevo-Smolensk  0.011538
# Mendeleyevsk-Yelabuga  0.003037
# Orlovskiy-Zimovniki  0.005560
# Rasskazovo-Uvarovo  0.008379
# Setun’-Tuchkovo  0.002658
# Kogalym-Noyabrsk  0.015131
# Murmansk-Olenegorsk  0.012579
# Ardon-Terek  0.003218
# Kinel’-Neftegorsk  0.007276
# Nyandoma-Sokol  0.028943
# Nevel’-Podol’sk  0.018314
# Murmansk-Zapolyarnyy  0.015623
# Nizhniy Tagil-Verkhnyaya Salda  0.005674
# Novomichurinsk-Ryazanskiy  0.006877
# Pochep-Starodub  0.008244
# Ivanovskoye-Odintsovo  0.001639
# Kumertau-Orenburg  0.013050
# Pechora-Yegor’yevsk  0.026802
# Magadan-Yelizovo  0.103095
# Priozërsk-Sosnovaya Polyana  0.010693
# Ramenki-Ryazan’  0.002584
# Balashov-Rtishchevo  0.010293
# Penza-Ruzayevka  0.009848
# Desnogorsk-Safonovo  0.011148
# Cheremkhovo-Zima  0.014016
# Nakhabino-Skhodnya  0.001508
# Tavda-Turinsk  0.014545
# Bratsk-Zheleznogorsk-Ilimskiy  0.024584
# Otradnoye-Vasyl'evsky Ostrov  0.002706
# Bogoroditsk-Yefremov  0.007104
# Mariinsk-Sharypovo  0.016138
# Belebey-Rayevskiy  0.008422
# Akhtyrskiy-Severskaya  0.004728
# Agryz-Mozhga  0.007596
# Chita-Ulan-Ude  0.063616
# Birobidzhan-Raychikhinsk  0.041367
# Sergiyev Posad-Sviblovo  0.002302
# Lesozavodsk-Yaroslavskiy  0.018405
# Ilanskiy-Tayshet  0.019180
# Kandalaksha-Kostomuksha  0.039059
# Belorechensk-Ust’-Labinsk  0.004545
# Novoural’sk-Sredneuralsk  0.004785
# Kulebaki-Pavlovo  0.008348
# Bodaybo-Chita  0.066103
# Aprelevka-Vnukovo  0.002289
# Gudermes-Khasavyurt  0.006237
# Satka-Zlatoust  0.006615
# Leninsk-Kuznetsky-Promyshlennaya  0.006053
# Iskitim-Toguchin  0.013049
# Anzhero-Sudzhensk-Beryozovsky  0.005537
# Kropotkin-Novopokrovskaya  0.004928
# Achkhoy-Martan-Urus-Martan  0.003286
# Buguruslan-Leninogorsk  0.010915
# Khimki-Vostochnoe Degunino  0.001424
# Dankov-Skopin  0.007837
# Elektrougli-Taganskiy  0.001289
# Torzhok-Tver  0.009322
# Michurinsk-Tambov  0.010240
# Achinsk-Divnogorsk  0.018697
# Arsk-Kukmor  0.009960
# Nal’chik-Nartkala  0.003310
# Cherkessk-Uchkeken  0.006350
# Kondrovo-Sukhinichi  0.010060
# Nerekhta-Yaroslavl  0.006712
# Chekhov-Troitsk  0.004258
# Kalach-na-Donu-Volgograd  0.011279
# Penza-Petrovsk  0.010447
# Rodniki-Shuya  0.004549
# Sertolovo-Sestroretsk  0.002316
# Mineralnye Vody-Nezlobnaya  0.003470
# Chudovo-Tosno  0.008911
# Altuf’yevskiy-Mytishchi  0.001552
# Kirovgrad-Nizhniy Tagil  0.005997
# Kulunda-Rubtsovsk  0.026844
# Chebarkul’-Plast  0.008369
# Kurovskoye-Voskresensk  0.003894
# Amursk-Sovetskaya Gavan’  0.040481
# Bogorodskoye-Omutninsk  0.016888
# Khanty-Mansiysk-Nyagan  0.033684
# Krasnogvardeyskoye-Ostrogozhsk  0.007855
# Chernushka-Yanaul  0.011474
# Rayevskiy-Sterlitamak  0.011380
# Kumertau-Saraktash  0.012166
# Beloyarskiy-Salekhard  0.040892
# Gubkin-Solntsevo  0.008621
# Konstantinovsk-Proletarsk  0.011038
# Lukhovitsy-Rybnoye  0.005539
# Klimovsk-Kudymkar  0.030756
# Aramil-Asbest  0.007074
# Bavly-Leninogorsk  0.008447
# Akademgorodok-Tynda  0.081329
# Armavir-Otradnaya  0.007054
# Balashikha-Shchelkovo  0.001579
# Baymak-Gay  0.012205
# Ishim-Omsk  0.040432
# Balashov-Povorino  0.010535
# Kashin-Uglich  0.006955
# Boksitogorsk-Borovichi  0.013832
# Boguchar-Millerovo  0.010301
# Kanash-Shumerlya  0.010616
# Tree weight 6.528069

# %%
edges_to_csv('mst_boruvka', s_edges)
